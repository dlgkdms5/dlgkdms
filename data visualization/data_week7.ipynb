# %%
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data visualization/seoul.xlsx')
df
# Out:
#              날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0    2011-01-01  108     -6.8    -10.4     -2.9
# 1    2011-01-02  108     -5.4     -8.5     -1.2
# 2    2011-01-03  108     -4.5     -8.5     -0.3
# 3    2011-01-04  108     -3.9     -7.4     -1.7
# 4    2011-01-05  108     -4.0     -7.7     -1.8
# ...         ...  ...      ...      ...      ...
# 3648 2020-12-27  108      5.8      1.4     10.0
# 3649 2020-12-28  108      6.7      4.2     11.4
# 3650 2020-12-29  108      0.1     -6.2      4.3
# 3651 2020-12-30  108    -10.9    -12.9     -6.2
# 3652 2020-12-31  108     -8.9    -12.9     -5.0
#
# [3653 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df['날짜'], df['평균기온(℃)'])
plt.plot(df['날짜'], df['최고기온(℃)'])
plt.plot(df['날짜'], df['최저기온(℃)'])
plt.xlabel('date')
plt.ylabel('temp')
plt.show()
