# %%
import pandas as pd

# %%
data = pd.read_csv('/content/cctv.csv')

# %%
data
# Out:
#                                                    순번    구분  \
# 0                                                   1   종로구
# 1                                                   2   중 구
# 2                                                   3   용산구
# 3                                                   4   성동구
# 4                                                   5   광진구
# 5                                                   6  동대문구
# 6                                                   7   중랑구
# 7                                                   8   성북구
# 8                                                   9   강북구
# 9                                                  10   도봉구
# 10                                                 11   노원구
# 11                                                 12   은평구
# 12                                                 13  서대문구
# 13                                                 14   마포구
# 14                                                 15   양천구
# ...

# %%
data.head()
# Out:
#   순번   구분  2015년 이전 설치된 CCTV   2016년  2017년  2018년  2019년  2020년  2021년  \
# 0  1  종로구               146.0   76.0  115.0  137.0   68.0  231.0   86.0
# 1  2  중 구               356.0  219.0  366.0  385.0  159.0  352.0  416.0
# 2  3  용산구                24.0  124.0  454.0  119.0  335.0  625.0  431.0
# 3  4  성동구              1295.0  228.0  881.0  383.0  477.0  386.0  294.0
# 4  5  광진구               247.0   38.0  660.0  465.0  710.0  194.0  744.0
#
#    2022년  2023년  2024년
# 0  234.0  924.0  322.0
# 1  137.0  135.0  593.0
# 2  457.0  411.0  629.0
# 3  170.0  320.0  204.0
# 4  276.0  348.0  954.0

# %%
data.tail(2)
# Out:
#                                                    순번   구분  \
# 24                                                 25  강동구
# 25  ※ 서울특별시 각 자치구의 CCTV 통합관제센터에 연계된 CCTV 현황입니다. (미...  NaN
#
#     2015년 이전 설치된 CCTV   2016년  2017년  2018년  2019년  2020년  2021년  2022년  \
# 24               725.0  202.0  273.0  377.0  356.0  614.0  262.0  381.0
# 25                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     2023년  2024년
# 24  359.0  689.0
# 25    NaN    NaN

# %%
data.shape
# Out:
# (26, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   순번                  26 non-null     object
#  1   구분                  25 non-null     object
#  2   2015년 이전 설치된 CCTV   25 non-null     float64
#  3   2016년               25 non-null     float64
#  4   2017년               25 non-null     float64
#  5   2018년               25 non-null     float64
#  6   2019년               25 non-null     float64
#  7   2020년               25 non-null     float64
#  8   2021년               25 non-null     float64
#  9   2022년               25 non-null     float64
#  10  2023년               25 non-null     float64
#  11  2024년               25 non-null     float64
# dtypes: float64(10), object(2)
# memory usage: 2.6+ KB

# %%
data.index
# Out:
# RangeIndex(start=0, stop=26, step=1)

# %%
data.columns
# Out:
# Index(['순번', '구분', '2015년 이전 설치된 CCTV ', '2016년', '2017년', '2018년', '2019년',
#        '2020년', '2021년', '2022년', '2023년', '2024년'],
#       dtype='object')

# %%
data["2024년"].max()
# Out:
# 1352.0

# %%
data["2024년"].min()
# Out:
# 80.0

# %%
data["2024년"].mean()
# Out:
# np.float64(680.12)

# %%
data.nlargest(1, "2024년")
# Out:
#     순번   구분  2015년 이전 설치된 CCTV   2016년  2017년  2018년  2019년  2020년  2021년  \
# 10  11  노원구               404.0  293.0  156.0  206.0  314.0  383.0  213.0
#
#     2022년  2023년   2024년
# 10  161.0  623.0  1352.0

# %%
data.nlargest(3, "2024년")
# Out:
#     순번   구분  2015년 이전 설치된 CCTV    2016년  2017년  2018년  2019년  2020년  2021년  \
# 10  11  노원구               404.0   293.0  156.0  206.0  314.0  383.0  213.0
# 22  23  강남구               590.0  1119.0  918.0  721.0  735.0  909.0  571.0
# 16  17  구로구                14.0   256.0  535.0  534.0  784.0  749.0  684.0
#
#     2022년  2023년   2024년
# 10  161.0  623.0  1352.0
# 22  527.0  923.0  1339.0
# 16  336.0  484.0  1318.0

# %%
data.sort_values(by="2024년")
# Out:
#                                                    순번    구분  \
# 8                                                   9   강북구
# 3                                                   4   성동구
# 15                                                 16   강서구
# 17                                                 18   금천구
# 0                                                   1   종로구
# 12                                                 13  서대문구
# 13                                                 14   마포구
# 18                                                 19  영등포구
# 9                                                  10   도봉구
# 5                                                   6  동대문구
# 14                                                 15   양천구
# 1                                                   2   중 구
# 11                                                 12   은평구
# 2                                                   3   용산구
# 23                                                 24   송파구
# ...

# %%
data.sort_values(by="2024년", ascending=False)
# Out:
#                                                    순번    구분  \
# 10                                                 11   노원구
# 22                                                 23   강남구
# 16                                                 17   구로구
# 20                                                 21   관악구
# 7                                                   8   성북구
# 4                                                   5   광진구
# 6                                                   7   중랑구
# 19                                                 20   동작구
# 21                                                 22   서초구
# 24                                                 25   강동구
# 23                                                 24   송파구
# 2                                                   3   용산구
# 11                                                 12   은평구
# 1                                                   2   중 구
# 14                                                 15   양천구
# ...
