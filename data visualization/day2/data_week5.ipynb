# %%
import pandas as pd
sr = pd.Series([70,80,90,100])
sr
# Out:
# 0     70
# 1     80
# 2     90
# 3    100
# dtype: int64

# %%
df = pd.DataFrame(['철수', '영희', '진숙', '완이'],[70,80,90,100])
df
# Out:
#       0
# 70   철수
# 80   영희
# 90   진숙
# 100  완이

# %%
data = {'이름': ['철수', '영희', '진숙', '완이'],
        '성별': ['남', '여', '여', '남'],
        '국어': [70,80,90,80],
        '영어': [90,70,95,85]}
df = pd.DataFrame(data)
df
# Out:
#    이름 성별  국어  영어
# 0  철수  남  70  90
# 1  영희  여  80  70
# 2  진숙  여  90  95
# 3  완이  남  80  85

# %%
df.count()
# Out:
# 이름    4
# 성별    4
# 국어    4
# 영어    4
# dtype: int64

# %%
df.max()
# Out:
# 이름    철수
# 성별     여
# 국어    90
# 영어    95
# dtype: object

# %%
df['국어'].max()
# Out:
# 90

# %%
df['국어'].mean()
# Out:
# np.float64(80.0)

# %%
df['국어']>70
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# Name: 국어, dtype: bool

# %%
df[df['국어']>70]
# Out:
#    이름 성별  국어  영어
# 1  영희  여  80  70
# 2  진숙  여  90  95
# 3  완이  남  80  85

# %%
df[df['영어']<=80]
# Out:
#    이름 성별  국어  영어
# 1  영희  여  80  70
